# %% [markdown]
# 需求
# --------
#
# 客戶:
# 1. 我想要一個 .py，執行後可以可以在當前目錄下自動創一個 weather.db 的檔案，如果 weather.db 已存在則繼續使用，不需重新創 db。 db 內容有一張 table 叫做 Location，欄位需要有 locationName startTime endTime parameterName parameterValue。
# 2. 取得當天天氣資料並記錄到 DB。

# %% [markdown]
# 目的
# -------
#
# 1. 練習如何使用公開資訊 API
# 2. 練習 SQL
# 3. 練習 python 基礎使用及使用 dict 與 list 等物件型態
# 4. 練習 python 內建 package 的基本使用(os、json、sqlite3、datetime 等)

# %% [markdown]
# 問題分析
# --------------
#
# 參考 https://www.latech.tw/2018/03/opendata.html 與 https://opendata.cwb.gov.tw/dist/opendata-swagger.html :
# 1. https://opendata.cwb.gov.tw/userLogin 登入後取得授權碼
# 2. 使用 requests 去 GET https://opendata.cwb.gov.tw/api/v1/rest/datastore/F-C0032-001?Authorization={{ 授權碼 }} 取得類似下圖 API json 資料
# 3. 運用 json 處理 requests 取回來的資料，取得 locationName startTime endTime parameterName parameterValue。
# 4. 運用 sqlite3 管理 db。
# 5. 可用 https://www.yunqa.de/delphi/products/sqlitespy/index 等相關軟體開啟 weather.db 觀看是否有 table 與 data 被記錄進 db 內。

# %%
from IPython.display import Image
Image("images/p1.png")

# %% [markdown]
# 回報方式
# ------------
#
# Messenger 私訊我 guthub 網址。

# %% [markdown]
# 期限
# -------
#
# 無限制
